# %%
import numpy as np
import pandas as pd
import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Flatten, Reshape
from keras.layers import Conv1D, MaxPooling1D,GlobalAveragePooling1D
from keras.layers import Input, Flatten, Dense, Dropout,Concatenate
#from keras.layers import LeakyReLU
from keras.layers.advanced_activations import LeakyReLU, PReLU
from keras.utils import np_utils
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from scipy import stats
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split

#dataset = pd.read_csv("sof.csv")
#x=dataset.iloc[0:409698,:].values
#y=dataset.iloc[409700:,:].values

#x = dataset[0:409699,:]
#y = dataset[409700:,:]
#y=dataset[0,1:3]
#y = y.transpose()
#x = x.transpose()
"""
dataset = np.loadtxt("sof.csv",delimiter=",")
x = dataset[0:409699,:]
y = dataset[409700:,0:3]

x=dataset[0:409700,[0,2,4]]
y=dataset[0:409700,[1,3,5]]

print(y)
"""

lables=[]

dataset = np.loadtxt("sof copy.csv",delimiter=",")

x=dataset[0:409700,0]
s=dataset[0:409700,2]
o=dataset[0:409700,4]
fet=np.concatenate((x, s,o), axis=None)

y=dataset[0:409700,1]
e=dataset[0:409700,3]
u=dataset[0:409700,5]

lables=np.concatenate((y, e,u), axis=None)

print("========\n",fet)
print(";;;;;;;;;;;;;;;;;\n",lables)


print("++++++++++++++++++++++++++++++++\n")
print(lables.shape)


print(fet.shape)

x_train, x_test, y_train, y_test = train_test_split(fet,lables, test_size=0.2, random_state=0)

x_train = x_train.reshape(x_train.shape[0],1,1)
y_train = y_train.reshape(y_train.shape[0],1)
print('New x_train shape: ', x_train.shape , 'New y_train shape: ',y_train.shape )

y_train_hot = np_utils.to_categorical(y_train-1,3)
print('New x_train shape: ', x_train.shape , 'New y_train shape: ',y_train_hot.shape )

"""

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

#print (y_train.shape)

x_train = x_train.reshape(x_train.shape[0],1)
x_train = x_train.reshape(x_train.shape[0],x_train.shape[1],1)

y_train = y_train.reshape(y_train.shape[0],1)
y_train = y_train.reshape(y_train.shape[0],x_train.shape[1],1)

print('New x_train shape: ', x_train.shape , 'New y_train shape: ',y_train.shape )

y_train_hot = np_utils.to_categorical(y_train-1,3)
print('New x_train shape: ', x_train.shape , 'New y_train shape: ',y_train_hot.shape )
"""
print (x_train.ndim)




model= Sequential()
model.add(Conv1D(4, 6, strides=1,activation='relu',border_mode='same',input_shape=(1,1), data_format='channels_first'))
model.add(Conv1D(4, 6, strides=1, activation='relu', border_mode='same'))
model.add(MaxPooling1D(4, strides=2))
model.add(Dropout(0.15))
model.add(Conv1D(4, 5, strides=1, activation='relu',padding='same',))
model.add(Conv1D(4, 5, strides=1, activation='relu', padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling1D(4, strides=2, padding='same'))
model.add(Dropout(0.15))
model.add(Conv1D(10, 4,strides=1 , activation='relu', padding='same'))
model.add(Conv1D(10, 4,strides=1 , activation='relu', padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling1D(10, strides=2, padding='same'))
model.add(Dropout(0.15))
model.add(Conv1D(10, 4, strides=1 , activation='relu', padding='same'))
model.add(Conv1D(10, 4, strides=1 , activation='relu', padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling1D(10, strides=2, padding='same'))
model.add(Dropout(0.15))
model.add(Conv1D(15, 4, strides=1 , activation='relu', padding='same'))
model.add(Conv1D(15, 4, strides=1 , padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling1D(15, strides=2 , padding='same'))
model.add(Dropout(0.15))
model.add(GlobalAveragePooling1D())
model.add(Dropout(0.15))
model.add(Dense (50 , activation='relu'))
model.add(Dropout(0.15))
model.add(Dense (20 , activation='relu'))
model.add(Dropout(0.15))
model.add(Dense (3,activation='softmax'))
print(model.summary())

"""
model= Sequential()
model.add(Conv1D(4, 6, strides=1,input_shape=(1,3)))
model.add(MaxPooling1D(4, strides=2))
model.add(Conv1D(4, 5, strides=1, padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling1D(4, strides=2))
model.add(Conv1D(10, 4,strides=1 , padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling1D(10, strides=2))

model.add(Conv1D(10, 4, strides=1 , padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling1D(10, strides=2))
model.add(Conv1D(15, 4, strides=1 , padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling1D(15, strides=2 , padding='same'))

model.add(GlobalAveragePooling1D())
model.add(Dropout(0.15))
model.add(Dense (50))
model.add(Dense (20))
model.add(Dense (5,activation='softmax'))
print(model.summary())
"""


# Compile model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Fit the model
model.fit(x_train, y_train_hot, epochs=20, batch_size=3, verbose=1)

# evaluate the model
#scores = model.evaluate(x_test, y_test, verbose=0)


#print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
#cvscores.append(scores[1] * 100)
#print("%.2f%% (+/- %.2f%%)" % (numpy.mean(cvscores), numpy.std(cvscores)))

#print("\n--- Fit the model ---\n")
# Out:
# ('========\n', array([ -24.,  -22.,  -17., ..., -155.,    6., -221.]))
# (';;;;;;;;;;;;;;;;;\n', array([1., 1., 1., ..., 3., 3., 3.]))
# ++++++++++++++++++++++++++++++++
#
# (1229100,)
# (1229100,)
# ('New x_train shape: ', (983280, 1, 1), 'New y_train shape: ', (983280, 1))
# ('New x_train shape: ', (983280, 1, 1), 'New y_train shape: ', (983280, 3))
# 3
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:94: UserWarning: Update your `Conv1D` call to the Keras 2 API: `Conv1D(4, 6, activation="relu", data_format="channels_first", input_shape=(1, 1), padding="same", strides=1)`
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:95: UserWarning: Update your `Conv1D` call to the Keras 2 API: `Conv1D(4, 6, padding="same", strides=1, activation="relu")`
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_131 (Conv1D)          (None, 4, 1)              28
# _________________________________________________________________
# conv1d_132 (Conv1D)          (None, 4, 4)              28
# _________________________________________________________________
# max_pooling1d_66 (MaxPooling (None, 1, 4)              0
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 1, 4)              0
# _________________________________________________________________
# conv1d_133 (Conv1D)          (None, 1, 4)              84
# _________________________________________________________________
# conv1d_134 (Conv1D)          (None, 1, 4)              84
# _________________________________________________________________
# leaky_re_lu_53 (LeakyReLU)   (None, 1, 4)              0
# _________________________________________________________________
# max_pooling1d_67 (MaxPooling (None, 1, 4)              0
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 1, 4)              0
# _________________________________________________________________
# conv1d_135 (Conv1D)          (None, 1, 10)             170
# _________________________________________________________________
# conv1d_136 (Conv1D)          (None, 1, 10)             410
# _________________________________________________________________
# leaky_re_lu_54 (LeakyReLU)   (None, 1, 10)             0
# _________________________________________________________________
# max_pooling1d_68 (MaxPooling (None, 1, 10)             0
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 1, 10)             0
# _________________________________________________________________
# conv1d_137 (Conv1D)          (None, 1, 10)             410
# _________________________________________________________________
# conv1d_138 (Conv1D)          (None, 1, 10)             410
# _________________________________________________________________
# leaky_re_lu_55 (LeakyReLU)   (None, 1, 10)             0
# _________________________________________________________________
# max_pooling1d_69 (MaxPooling (None, 1, 10)             0
# _________________________________________________________________
# dropout_45 (Dropout)         (None, 1, 10)             0
# _________________________________________________________________
# conv1d_139 (Conv1D)          (None, 1, 15)             615
# _________________________________________________________________
# conv1d_140 (Conv1D)          (None, 1, 15)             915
# _________________________________________________________________
# leaky_re_lu_56 (LeakyReLU)   (None, 1, 15)             0
# _________________________________________________________________
# max_pooling1d_70 (MaxPooling (None, 1, 15)             0
# _________________________________________________________________
# dropout_46 (Dropout)         (None, 1, 15)             0
# _________________________________________________________________
# global_average_pooling1d_5 ( (None, 15)                0
# _________________________________________________________________
# dropout_47 (Dropout)         (None, 15)                0
# _________________________________________________________________
# dense_40 (Dense)             (None, 50)                800
# _________________________________________________________________
# dropout_48 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_41 (Dense)             (None, 20)                1020
# _________________________________________________________________
# dropout_49 (Dropout)         (None, 20)                0
# _________________________________________________________________
# dense_42 (Dense)             (None, 3)                 63
# =================================================================
# Total params: 5,037
# Trainable params: 5,037
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/20
#   4515/983280 [..............................] - ETA: 1:57:28 - loss: 1.0989 - acc: 0.3320
