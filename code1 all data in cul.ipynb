# %%
### import numpy as np
import pandas as pd
import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Flatten, Reshape
from keras.layers import Conv1D, MaxPooling1D,GlobalAveragePooling1D
from keras.layers import Input, Flatten, Dense, Dropout,Concatenate
#from keras.layers import LeakyReLU
from keras.layers.advanced_activations import LeakyReLU, PReLU
from keras.utils import np_utils
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from scipy import stats
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split

#dataset = pd.read_csv("sof.csv")
#x=dataset.iloc[0:409698,:].values
#y=dataset.iloc[409700:,:].values

#x = dataset[0:409699,:]
#y = dataset[409700:,:]
#y=dataset[0,1:3]
#y = y.transpose()
#x = x.transpose()
"""
dataset = np.loadtxt("sof.csv",delimiter=",")
x = dataset[0:409699,:]
y = dataset[409700:,0:3]
"""

lables=[]

dataset = np.loadtxt("sof copy.csv",delimiter=",")
x=dataset[0:409700,0]
s=dataset[0:409700,2]
o=dataset[0:409700,4]
fet=np.concatenate((x, s,o), axis=None)

y=dataset[0:409700,1]
e=dataset[0:409700,3]
u=dataset[0:409700,5]

lables=np.concatenate((y, e,u), axis=None)

print("========\n",fet)
print(";;;;;;;;;;;;;;;;;\n",lables)


print("++++++++++++++++++++++++++++++++\n")
print(lables.shape)


print(fet.shape)


#x = x.reshape(x.shape[0], x.shape[1],1)
#y = y.reshape(y.shape[0],y.shape[1],1)
#print('New x_train shape: ', x.shape , 'New y_train shape: ',y.shape )

#y_hot = np_utils.to_categorical(y_train-1,3)
#print('New x_train shape: ', x.shape , 'New y_train shape: ',y_hot.shape )


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

#print (y_train.shape)


x_train = x_train.reshape(x_train.shape[0],1)
y_train = y_train.reshape(y_train.shape[0],1,1)
print('New x_train shape: ', x_train.shape , 'New y_train shape: ',y_train.shape )

y_train_hot = np_utils.to_categorical(y_train-1,3)
print('New x_train shape: ', x_train.shape , 'New y_train shape: ',y_train_hot.shape )


print (x_train.ndim)

model= Sequential()
model.add(Conv1D(4, 6, strides=1,activation='relu',input_shape=(1229100,1), data_format='channels_first'))
model.add(Conv1D(4, 6, strides=1, activation='relu', padding='same'))
model.add(MaxPooling1D(4, strides=2))
model.add(Dropout(0.15))

model.add(Conv1D(4, 5, strides=1, activation='relu', padding='same'))
model.add(Conv1D(4, 5, strides=1, activation='relu', padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling1D(4, strides=2))
model.add(Dropout(0.15))


model.add(Conv1D(10, 4,strides=1 , activation='relu', padding='same'))
model.add(Conv1D(10, 4,strides=1 , activation='relu', padding='same'))

model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling1D(10, strides=2))
model.add(Dropout(0.15))

model.add(Conv1D(10, 4, strides=1 , activation='relu', padding='same'))
model.add(Conv1D(10, 4, strides=1 , activation='relu', padding='same'))

model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling1D(10, strides=2))
model.add(Dropout(0.15))

model.add(Conv1D(15, 4, strides=1 , activation='relu', padding='same'))
model.add(Conv1D(15, 4, strides=1 , padding='same'))


model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling1D(15, strides=2 , padding='same'))
#model.add(Dropout(0.15))


model.add(GlobalAveragePooling1D())
model.add(Dropout(0.15))
model.add(Dense (50))
model.add(Dense (20))
model.add(Dense (5,activation='softmax'))
print(model.summary())
"""

model= Sequential()
model.add(Conv1D(4, 6, strides=1,input_shape=(1,3)))
model.add(MaxPooling1D(4, strides=2))
model.add(Conv1D(4, 5, strides=1, padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling1D(4, strides=2))
model.add(Conv1D(10, 4,strides=1 , padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling1D(10, strides=2))

model.add(Conv1D(10, 4, strides=1 , padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling1D(10, strides=2))
model.add(Conv1D(15, 4, strides=1 , padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling1D(15, strides=2 , padding='same'))

model.add(GlobalAveragePooling1D())
model.add(Dropout(0.15))
model.add(Dense (50))
model.add(Dense (20))
model.add(Dense (5,activation='softmax'))
print(model.summary())
"""


# Compile model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Fit the model
model.fit(x_train, y_train, epochs=20, batch_size=3, verbose=0)

# evaluate the model
#scores = model.evaluate(x_test, y_test, verbose=0)


#print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
#cvscores.append(scores[1] * 100)
#print("%.2f%% (+/- %.2f%%)" % (numpy.mean(cvscores), numpy.std(cvscores)))

#print("\n--- Fit the model ---\n")
# Out:
# ('========\n', array([ -24.,  -22.,  -17., ..., -155.,    6., -221.]))
# (';;;;;;;;;;;;;;;;;\n', array([1., 1., 1., ..., 3., 3., 3.]))
# ++++++++++++++++++++++++++++++++
#
# (1229100,)
# (1229100,)
# ('New x_train shape: ', (327760, 1), 'New y_train shape: ', (327760, 1, 1))
# ('New x_train shape: ', (327760, 1), 'New y_train shape: ', (327760, 1, 3))
# 2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-77da085da67a> in <module>()
#      79
#      80 model= Sequential()
# ---> 81 model.add(Conv1D(4, 6, strides=1,activation='relu',input_shape=(1229100,1), data_format='channels_first'))
#      82 model.add(Conv1D(4, 6, strides=1, activation='relu', padding='same'))
#      83 model.add(MaxPooling1D(4, strides=2))
#
# /anaconda2/lib/python2.7/site-packages/keras/engine/sequential.pyc in add(self, layer)
#     163                     # and create the node connecting the current layer
#     164                     # to the input layer we just created.
# --> 165                     layer(x)
#     166                     set_inputs = True
#     167             else:
#
# /anaconda2/lib/python2.7/site-packages/keras/engine/base_layer.pyc in __call__(self, inputs, **kwargs)
#     455             # Actually call the layer,
#     456             # collecting output(s), mask(s), and shape(s).
# --> 457             output = self.call(inputs, **kwargs)
#     458             output_mask = self.compute_mask(inputs, previous_mask)
#     459
#
# /anaconda2/lib/python2.7/site-packages/keras/layers/convolutional.pyc in call(self, inputs)
#     161                 padding=self.padding,
#     162                 data_format=self.data_format,
# --> 163                 dilation_rate=self.dilation_rate[0])
#     164         if self.rank == 2:
#     165             outputs = K.conv2d(
#
# /anaconda2/lib/python2.7/site-packages/keras/backend/tensorflow_backend.pyc in conv1d(x, kernel, strides, padding, data_format, dilation_rate)
#    3609         strides=(strides,),
#    3610         padding=padding,
# -> 3611         data_format=tf_data_format)
#    3612
#    3613     if data_format == 'channels_first' and tf_data_format == 'NWC':
#
# /anaconda2/lib/python2.7/site-packages/tensorflow/python/ops/nn_ops.pyc in convolution(input, filter, padding, strides, dilation_rate, name, data_format)
#     778         name=name,
#     779         data_format=data_format)
# --> 780     return op(input, filter)
#     781
#     782
#
# /anaconda2/lib/python2.7/site-packages/tensorflow/python/ops/nn_ops.pyc in __call__(self, inp, filter)
#     866
#     867   def __call__(self, inp, filter):  # pylint: disable=redefined-builtin
# --> 868     return self.conv_op(inp, filter)
#     869
#     870
#
# /anaconda2/lib/python2.7/site-packages/tensorflow/python/ops/nn_ops.pyc in __call__(self, inp, filter)
#     518
#     519   def __call__(self, inp, filter):  # pylint: disable=redefined-builtin
# --> 520     return self.call(inp, filter)
#     521
#     522
#
# /anaconda2/lib/python2.7/site-packages/tensorflow/python/ops/nn_ops.pyc in __call__(self, inp, filter)
#     202         padding=self.padding,
#     203         data_format=self.data_format,
# --> 204         name=self.name)
#     205
#     206
#
# /anaconda2/lib/python2.7/site-packages/tensorflow/python/ops/nn_ops.pyc in _conv1d(self, input, filter, strides, padding, data_format, name)
#     191         padding=padding,
#     192         data_format=data_format,
# --> 193         name=name)
#     194
#     195   # pylint: enable=redefined-builtin
#
# /anaconda2/lib/python2.7/site-packages/tensorflow/python/util/deprecation.pyc in new_func(*args, **kwargs)
#     517                   func.__module__, arg_name, arg_value, 'in a future version'
#     518                   if date is None else ('after %s' % date), instructions)
# --> 519       return func(*args, **kwargs)
#     520     return tf_decorator.make_decorator(func, new_func, 'deprecated',
#     521                                        _add_deprecated_arg_notice_to_docstring(
#
# /anaconda2/lib/python2.7/site-packages/tensorflow/python/util/deprecation.pyc in new_func(*args, **kwargs)
#     517                   func.__module__, arg_name, arg_value, 'in a future version'
#     518                   if date is None else ('after %s' % date), instructions)
# --> 519       return func(*args, **kwargs)
#     520     return tf_decorator.make_decorator(func, new_func, 'deprecated',
#     521                                        _add_deprecated_arg_notice_to_docstring(
#
# /anaconda2/lib/python2.7/site-packages/tensorflow/python/ops/nn_ops.pyc in conv1d(value, filters, stride, padding, use_cudnn_on_gpu, data_format, name)
#    2483         padding,
#    2484         use_cudnn_on_gpu=use_cudnn_on_gpu,
# -> 2485         data_format=data_format)
#    2486     return array_ops.squeeze(result, [spatial_start_dim])
#    2487
#
# /anaconda2/lib/python2.7/site-packages/tensorflow/python/ops/gen_nn_ops.pyc in conv2d(input, filter, strides, padding, use_cudnn_on_gpu, data_format, dilations, name)
#     954         "Conv2D", input=input, filter=filter, strides=strides,
#     955         padding=padding, use_cudnn_on_gpu=use_cudnn_on_gpu,
# --> 956         data_format=data_format, dilations=dilations, name=name)
#     957     _result = _op.outputs[:]
#     958     _inputs_flat = _op.inputs
#
# /anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/op_def_library.pyc in _apply_op_helper(self, op_type_name, name, **keywords)
#     785         op = g.create_op(op_type_name, inputs, output_types, name=scope,
#     786                          input_types=input_types, attrs=attr_protos,
# --> 787                          op_def=op_def)
#     788       return output_structure, op_def.is_stateful, op
#     789
#
# /anaconda2/lib/python2.7/site-packages/tensorflow/python/util/deprecation.pyc in new_func(*args, **kwargs)
#     452                 'in a future version' if date is None else ('after %s' % date),
#     453                 instructions)
# --> 454       return func(*args, **kwargs)
#     455     return tf_decorator.make_decorator(func, new_func, 'deprecated',
#     456                                        _add_deprecated_arg_notice_to_docstring(
#
# /anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/ops.pyc in create_op(***failed resolving arguments***)
#    3153           input_types=input_types,
#    3154           original_op=self._default_original_op,
# -> 3155           op_def=op_def)
#    3156       self._create_op_helper(ret, compute_device=compute_device)
#    3157     return ret
#
# /anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/ops.pyc in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    1729           op_def, inputs, node_def.attr)
#    1730       self._c_op = _create_c_op(self._graph, node_def, grouped_inputs,
# -> 1731                                 control_input_ops)
#    1732
#    1733     # Initialize self._outputs.
#
# /anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/ops.pyc in _create_c_op(graph, node_def, inputs, control_inputs)
#    1577   except errors.InvalidArgumentError as e:
#    1578     # Convert to ValueError for backwards compatibility.
# -> 1579     raise ValueError(str(e))
#    1580
#    1581   return c_op
#
# ValueError: Negative dimension size caused by subtracting 6 from 1 for 'conv1d_50/convolution/Conv2D' (op: 'Conv2D') with input shapes: [?,1,1,1229100], [1,6,1229100,4].
